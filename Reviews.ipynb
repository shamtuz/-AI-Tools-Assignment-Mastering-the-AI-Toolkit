# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products.csv')

# View columns
print(df.columns)

# Sample 5 random reviews
sample_reviews = df['reviews.text'].dropna().sample(5).tolist()

# Print to verify
for i, review in enumerate(sample_reviews):
    print(f"Review {i+1}: {review}")
# Out:
# Index(['id', 'dateAdded', 'dateUpdated', 'name', 'asins', 'brand',
#        'categories', 'primaryCategories', 'imageURLs', 'keys', 'manufacturer',
#        'manufacturerNumber', 'reviews.date', 'reviews.dateAdded',
#        'reviews.dateSeen', 'reviews.doRecommend', 'reviews.id',
#        'reviews.numHelpful', 'reviews.rating', 'reviews.sourceURLs',
#        'reviews.text', 'reviews.title', 'reviews.username', 'sourceURLs'],
#       dtype='object')
# Review 1: I have had this for several weeks. It works great. I am very satisfied with it so far.
# Review 2: My wife said I‚Äôm developing a ‚ÄúStar Trek‚Äù home...while I‚Äôm still learning what all I can do with this over the regular Echo, I am looking forward to getting my Ring Doorbell installed! Great product, I can rave enough about them!!!
# Review 3: did not expect this kind of quality for the price I paid. very surprised. nice product.
# ...

# %%
# 🛠 If needed (in Jupyter only):
# !pip install spacy textblob
# !python -m spacy download en_core_web_sm

import pandas as pd
import spacy
from textblob import TextBlob

# ✅ Load spaCy model
nlp = spacy.load("en_core_web_sm")

# ✅ Load the Amazon reviews CSV
df = pd.read_csv("Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products.csv", encoding="ISO-8859-1")

# ✅ Check actual column names (just once)
print("🧾 CSV Columns:")
print(df.columns.tolist())  # Uncomment this to inspect if unsure

# ✅ Use the correct column that contains the reviews
# Most common: 'reviews.text'
review_col = 'reviews.text'

# Drop missing reviews and sample 5
sample_reviews = df[review_col].dropna().sample(5, random_state=1).tolist()

# ✅ Process each review
for i, review in enumerate(sample_reviews):
    print(f"\n📝 Review {i+1}: {review}\n")

    # --- Named Entity Recognition ---
    doc = nlp(review)
    entities = [(ent.text, ent.label_) for ent in doc.ents if ent.label_ in ["PRODUCT", "ORG"]]

    print("🧠 Named Entities (Products/Brands):")
    if entities:
        for ent in entities:
            print(f"  - {ent[0]} ({ent[1]})")
    else:
        print("  - No relevant entities found.")

    # --- Sentiment Analysis using TextBlob ---
    polarity = TextBlob(review).sentiment.polarity
    sentiment = "Positive" if polarity > 0 else "Negative" if polarity < 0 else "Neutral"
    print(f"\n💬 Sentiment: {sentiment} ({polarity:.2f})")
    print("-" * 60)

# %%
# 🛠 If needed (in Jupyter only):
# !pip install spacy textblob
# !python -m spacy download en_core_web_sm

import pandas as pd
import spacy
from textblob import TextBlob

# ✅ Load spaCy model
nlp = spacy.load("en_core_web_sm")

# ✅ Load the Amazon reviews CSV
df = pd.read_csv("Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products.csv", encoding="ISO-8859-1")

# ✅ Check actual column names (just once)
print("🧾 CSV Columns:")
print(df.columns.tolist())  # Uncomment this to inspect if unsure

# ✅ Use the correct column that contains the reviews
# Most common: 'reviews.text'
review_col = 'reviews.text'

# Drop missing reviews and sample 5
sample_reviews = df[review_col].dropna().sample(5, random_state=1).tolist()

# ✅ Process each review
for i, review in enumerate(sample_reviews):
    print(f"\n📝 Review {i+1}: {review}\n")

    # --- Named Entity Recognition ---
    doc = nlp(review)
    entities = [(ent.text, ent.label_) for ent in doc.ents if ent.label_ in ["PRODUCT", "ORG"]]

    print("🧠 Named Entities (Products/Brands):")
    if entities:
        for ent in entities:
            print(f"  - {ent[0]} ({ent[1]})")
    else:
        print("  - No relevant entities found.")

    # --- Sentiment Analysis using TextBlob ---
    polarity = TextBlob(review).sentiment.polarity
    sentiment = "Positive" if polarity > 0 else "Negative" if polarity < 0 else "Neutral"
    print(f"\n💬 Sentiment: {sentiment} ({polarity:.2f})")
    print("-" * 60)

# %%
from textblob import TextBlob

text = "I love the Samsung Galaxy phone!"
polarity = TextBlob(text).sentiment.polarity
print(f"Sentiment polarity: {polarity}")
# Out:
# Sentiment polarity: 0.625

# %%
# 🛠 If needed (in Jupyter only):
# !pip install spacy textblob
# !python -m spacy download en_core_web_sm

import pandas as pd
import spacy
from textblob import TextBlob

# ✅ Load spaCy model
nlp = spacy.load("en_core_web_sm")

# ✅ Load the Amazon reviews CSV
df = pd.read_csv("Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products.csv", encoding="ISO-8859-1")

# ✅ Check actual column names (just once)
print("🧾 CSV Columns:")
print(df.columns.tolist())  # Uncomment this to inspect if unsure

# ✅ Use the correct column that contains the reviews
# Most common: 'reviews.text'
review_col = 'reviews.text'

# Drop missing reviews and sample 5
sample_reviews = df[review_col].dropna().sample(5, random_state=1).tolist()

# ✅ Process each review
for i, review in enumerate(sample_reviews):
    print(f"\n📝 Review {i+1}: {review}\n")

    # --- Named Entity Recognition ---
    doc = nlp(review)
    entities = [(ent.text, ent.label_) for ent in doc.ents if ent.label_ in ["PRODUCT", "ORG"]]

    print("🧠 Named Entities (Products/Brands):")
    if entities:
        for ent in entities:
            print(f"  - {ent[0]} ({ent[1]})")
    else:
        print("  - No relevant entities found.")

    # --- Sentiment Analysis using TextBlob ---
    polarity = TextBlob(review).sentiment.polarity
    sentiment = "Positive" if polarity > 0 else "Negative" if polarity < 0 else "Neutral"
    print(f"\n💬 Sentiment: {sentiment} ({polarity:.2f})")
    print("-" * 60)
# Out:
# 🧾 CSV Columns:
# ['ï»¿id', 'dateAdded', 'dateUpdated', 'name', 'asins', 'brand', 'categories', 'primaryCategories', 'imageURLs', 'keys', 'manufacturer', 'manufacturerNumber', 'reviews.date', 'reviews.dateAdded', 'reviews.dateSeen', 'reviews.doRecommend', 'reviews.id', 'reviews.numHelpful', 'reviews.rating', 'reviews.sourceURLs', 'reviews.text', 'reviews.title', 'reviews.username', 'sourceURLs']
#
# 📝 Review 1: I bought these for my niece and nephews for Christmas. They love them! They know how to turn them on and locate an app. I love being able to set time limits so they aren't on their tablets very often! Great investment!
#
# 🧠 Named Entities (Products/Brands):
#   - No relevant entities found.
#
# 💬 Sentiment: Positive (0.57)
# ------------------------------------------------------------
#
# ...

# %%
# 🛠 Task 3: NLP with spaCy + TextBlob

# Required installations (run in Jupyter or CMD before running this script):
# !pip install spacy textblob pandas nltk
# !python -m spacy download en_core_web_sm

import pandas as pd
import spacy
from textblob import TextBlob

# ✅ Load spaCy English model
nlp = spacy.load("en_core_web_sm")

# ✅ Load Amazon Reviews CSV
# Ensure the file name matches your download
df = pd.read_csv("Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products.csv", encoding="ISO-8859-1")

# ✅ Check available columns
print("\n📄 Available Columns:", df.columns.tolist())

# ✅ Choose the column with review text
review_col = 'reviews.text'  # Change this if the column is different

# ✅ Drop missing reviews and sample 5
sample_reviews = df[review_col].dropna().sample(5, random_state=42).tolist()

# ✅ Process each review
for i, review in enumerate(sample_reviews):
    print(f"\n📝 Review {i+1}:\n{review}\n")

    # --- Named Entity Recognition (NER) ---
    doc = nlp(review)
    product_entities = [(ent.text, ent.label_) for ent in doc.ents if ent.label_ in ['PRODUCT', 'ORG']]

    print("🧠 Named Entities (Product Names / Brands):")
    if product_entities:
        for ent_text, ent_label in product_entities:
            print(f"  - {ent_text} ({ent_label})")
    else:
        print("  - No product/brand entities found.")

    # --- Sentiment Analysis using TextBlob ---
    polarity = TextBlob(review).sentiment.polarity
    sentiment = "Positive" if polarity > 0 else "Negative" if polarity < 0 else "Neutral"

    print(f"\n💬 Sentiment: {sentiment} ({polarity:.2f})")
    print("-" * 60)
# Out:
# 📄 Available Columns: ['ï»¿id', 'dateAdded', 'dateUpdated', 'name', 'asins', 'brand', 'categories', 'primaryCategories', 'imageURLs', 'keys', 'manufacturer', 'manufacturerNumber', 'reviews.date', 'reviews.dateAdded', 'reviews.dateSeen', 'reviews.doRecommend', 'reviews.id', 'reviews.numHelpful', 'reviews.rating', 'reviews.sourceURLs', 'reviews.text', 'reviews.title', 'reviews.username', 'sourceURLs']
#
# 📝 Review 1:
# IFeel confident purchasing products from Best Buy due to protection coverage
#
# 🧠 Named Entities (Product Names / Brands):
#   - No product/brand entities found.
#
# 💬 Sentiment: Positive (0.46)
# ------------------------------------------------------------
#
# 📝 Review 2:
# Great tablet for my 3 yr old. Love the profile options and parental controls!
#
# 🧠 Named Entities (Product Names / Brands):
#   - No product/brand entities found.
#
# 💬 Sentiment: Positive (0.51)
# ------------------------------------------------------------
#
# 📝 Review 3:
# ...
